# %% [markdown]
# # Imports and Initializations

# %%
import numpy as np
import tensorflow as tf
import requests
import cv2
import os
import matplotlib.pyplot as plt
import shutil
import zipfile
import imageio
from tensorflow.keras.models import save_model
import time

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
IMAGE_WIDTH = 128
IMAGE_HEIGHT = 128
SEQUENCE_LENGTH = 30

# %% [markdown]
# # Loading Dataset 1 (UR Fall Detection Dataset)

# %% [markdown]
# Run Code Below if Downloading Dataset for the First Time:

# %%
# !mkdir camera_1_videos_fall
# !mkdir camera_0_videos_fall
# !mkdir adl_videos
# !mkdir unzipped_camera_0_videos
# !mkdir unzipped_camera_1_videos
# !mkdir unzipped_adl_videos
# !mkdir fall_tensors
# !mkdir adl_tensors

# %%
def download_file(url, local_filename):
    response = requests.get(url, stream=True)
    response.raise_for_status()
    with open(local_filename, 'wb') as file:
        for chunk in response.iter_content(chunk_size=8192):
            file.write(chunk)

# %%
def unzip_file(zip_path, extract_to):
    os.makedirs(extract_to, exist_ok=True)
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_to)

# %%
def download_fall_videos():
  base_url = 'http://fenix.ur.edu.pl/~mkepski/ds/data/'
  for i in range(30):
    num_string = '0'+ str(i+1) if i+1 < 10 else str(i+1)
    cam0_url = base_url + 'fall-' + num_string + '-cam0-rgb.zip'
    cam1_url = base_url + 'fall-' + num_string + '-cam1-rgb.zip'
    download_file(cam0_url, '/content/camera_0_videos_fall/fall-' + num_string + '-cam0-rgb.zip')
    download_file(cam1_url, '/content/camera_1_videos_fall/fall-' + num_string + '-cam1-rgb.zip')
    unzip_file('/content/camera_0_videos_fall/fall-' + num_string + '-cam0-rgb.zip', '/content/unzipped_camera_0_videos')
    unzip_file('/content/camera_1_videos_fall/fall-' + num_string + '-cam1-rgb.zip', '/content/unzipped_camera_1_videos')

# %%
def download_adl_videos():
    base_url = 'http://fenix.ur.edu.pl/~mkepski/ds/data/'
    for i in range(40):
      num_string = '0'+ str(i+1) if i+1 < 10 else str(i+1)
      adl_url = base_url + 'adl-' + num_string + '-cam0-rgb.zip'
      download_file(adl_url, '/content/adl_videos/adl-' + num_string + '-cam0-rgb.zip')
      unzip_file('/content/adl_videos/adl-' + num_string + '-cam0-rgb.zip', '/content/unzipped_adl_videos')

# %%
download_fall_videos()
download_adl_videos()

# %%
def find_split_num(length):
  return length // SEQUENCE_LENGTH

# %%
def load_images_from_folder(folder,IMAGE_HEIGHT,IMAGE_WIDTH):
    images = []
    for i in range(len(os.listdir(folder))):
            num_string = '0'+ str(i+1) if i+1 < 10 else str(i+1)
            num_string = '0' + num_string if i+1<100 else str(i+1)
            end_part = folder.split('/')[-1]
            filename = folder +'/'+ end_part + '-' + num_string + '.png'
            img = cv2.imread(filename)
            img = cv2.resize(img,(IMAGE_HEIGHT,IMAGE_WIDTH))
            img = img.astype('float32') / 255.0
            if img is not None:
                images.append(img)
    return images

# %%
def array_to_mp4(array, output_file, fps=5):
    num_frames, height, width, channels = array.shape
    array = (array * 255).astype(np.uint8)
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    video_writer = cv2.VideoWriter(output_file, fourcc, fps, (width, height))
    for i in range(num_frames):
        frame = array[i]
        video_writer.write(frame)
    video_writer.release()

# %%
def video_to_frames(video_path):
    video_capture = cv2.VideoCapture(video_path)
    if not video_capture.isOpened():
        return
    frame_number = 0
    frame_list = []
    while True:
        ret, frame = video_capture.read()
        if not ret:
            break
        frame_number += 1
        frame_list.append(frame)
    video_capture.release()
    return frame_list

# %%
def split_array_by_num(arr):
  return arr[::find_split_num(len(arr))]

# %%
for i in range(1,31):
  num_string = '0'+ str(i) if i < 10 else str(i)
  np.save('/content/fall_tensors/' + f"camera_0_{str(i)}", split_array_by_num(load_images_from_folder('/content/unzipped_camera_0_videos/fall-'+num_string+'-cam0-rgb',IMAGE_HEIGHT,IMAGE_WIDTH)))
  np.save('/content/fall_tensors/' + f"camera_1_{str(i)}", split_array_by_num(load_images_from_folder('/content/unzipped_camera_1_videos/fall-'+num_string+'-cam1-rgb',IMAGE_HEIGHT,IMAGE_WIDTH)))

# %%
for i in range(1,41):
  num_string = '0'+ str(i) if i < 10 else str(i)
  np.save('/content/adl_tensors/' + f"adl_{str(i)}", split_array_by_num(load_images_from_folder('/content/unzipped_adl_videos/adl-'+num_string+'-cam0-rgb',IMAGE_HEIGHT,IMAGE_WIDTH)))

# %%
def generate_video_dataset():
  dataset = tf.data.Dataset.from_tensor_slices(([np.load("/content/fall_tensors/camera_0_1.npy")], [1]))
  dataset = dataset.concatenate(tf.data.Dataset.from_tensor_slices(([np.load("/content/fall_tensors/camera_1_1.npy")], [1])))
  for i in range(2, 31):
    dataset = dataset.concatenate(tf.data.Dataset.from_tensor_slices(([np.load(f"/content/fall_tensors/camera_0_{i}.npy")], [1])))
    dataset = dataset.concatenate(tf.data.Dataset.from_tensor_slices(([np.load(f"/content/fall_tensors/camera_1_{i}.npy")], [1])))
    print("Fall", i)
  for i in range(1, 41):
    dataset = dataset.concatenate(tf.data.Dataset.from_tensor_slices(([np.load(f"/content/adl_tensors/adl_{i}.npy")], [0])))
    print("ADL", i)
  return dataset

# %%
dataset1 = generate_video_dataset()

# %% [markdown]
# Run this if dataset is already downloaded to Drive

# %%
# !mkdir Dataset1
# !mkdir Dataset1/12321685308842595500
# !mkdir Dataset1/12321685308842595500/00000000.shard
shutil.copy("/content/drive/MyDrive/Dataset/12321685308842595500/00000000.shard/00000000.snapshot", "/content/Dataset1/12321685308842595500/00000000.shard")
shutil.copy("/content/drive/MyDrive/Dataset/dataset_spec.pb", "/content/Dataset1")
shutil.copy("/content/drive/MyDrive/Dataset/snapshot.metadata", "/content/Dataset1")

dataset1 = tf.data.Dataset.load("/content/Dataset1")

# %% [markdown]
# # Loading Dataset 2 (IRO Multiple Cameras Fall Data Set)

# %% [markdown]
# Run Code Below if Downloading Dataset for the First Time:

# %%
# !curl -O https://www.iro.umontreal.ca/~labimage/Dataset/dataset.zip

# %%
# !unzip /content/dataset.zip

# %%
def scale_and_resize_list_of_frames(frames):
  resized_frames = []
  for frame in frames:
    resized_frames.append(cv2.resize(frame,(128,128))/255.0)
  return resized_frames

# %%
for i in range(1,20):
  numStr = f"0{i}" if i < 10 else str(i)
  l = video_to_frames(f'/content/dataset/chute{numStr}/cam1.avi')
  l_resized = scale_and_resize_list_of_frames(l)
  l_resized = l_resized[len(l_resized)//3:2*len(l_resized)//3]
  l_resized = split_array_by_num(l_resized)
  np.array(l_resized).shape
  np.save(f'/content/fall_videos/fall_video_{i}', np.array(l_resized))

# %%
for i in range(23,25):
  for j in range(1,9):
    l = video_to_frames(f'/content/dataset/chute{i}/cam{j}.avi')
    l_resized = scale_and_resize_list_of_frames(l)
    l_resized = l_resized[len(l_resized)//3:2*len(l_resized)//3]
    l_resized = split_array_by_num(l_resized)
    np.array(l_resized).shape
    np.save(f'/content/non_fall_videos/non_fall_video_{(i - 23) * 23 + j}', np.array(l_resized))

# %%
def generate_video_dataset():
  dataset = tf.data.Dataset.from_tensor_slices(([np.load("/content/fall_videos/fall_video_1.npy")], [1]))
  for i in range(2, 20):
    dataset = dataset.concatenate(tf.data.Dataset.from_tensor_slices(([np.load(f"/content/fall_videos/fall_video_{i}.npy")], [1])))
  for i in range(1, 17):
    dataset = dataset.concatenate(tf.data.Dataset.from_tensor_slices(([np.load(f"/content/non_fall_videos/non_fall_video_{i}.npy")], [0])))
  return dataset

# %%
dataset2 = generate_video_dataset()

# %% [markdown]
# Run this if dataset is already downloaded to Drive:

# %%
# Dataset 2
# !mkdir Dataset2
# !mkdir Dataset2/16619387829981642527
# !mkdir Dataset2/16619387829981642527/00000000.shard
shutil.copy("/content/drive/MyDrive/IRO_Dataset/16619387829981642527/00000000.shard/00000000.snapshot", "/content/Dataset2/16619387829981642527/00000000.shard")
shutil.copy("/content/drive/MyDrive/IRO_Dataset/dataset_spec.pb", "/content/Dataset2")
shutil.copy("/content/drive/MyDrive/IRO_Dataset/snapshot.metadata", "/content/Dataset2")

dataset2 = tf.data.Dataset.load("/content/Dataset2")

# %% [markdown]
# # Loading Dataset 3 (Mendeley CAUCAfall Dataset)

# %% [markdown]
# Run Code Below if Downloading Dataset for the First Time:

# %%
# !mkdir fall_tensors
# !mkdir adl_tensors

# %%
# !curl -L -o CAUCAFall.zip "https://data.mendeley.com/public-files/datasets/7w7fccy7ky/4/files/CAUCAFall.zip"

# %%
# !unzip CAUCAFall.zip -d CAUCAFall

# %%
falls = [r"Fall backwards", r"Fall forward", r"Fall left", r"Fall right", r"Fall sitting"]
adls = [r"Hop",r"Kneel", r"Pick up object", r"Sit down", r"Walk"]

# %%
basePath = "/content/CAUCAFall"
fall_videos_list = []
non_fall_videos_list = []
for f in os.listdir(basePath):
  if "Subject" not in f:
    continue
  for fs in os.listdir(basePath + "/"+ f):
    if "DS" in fs:
      continue
    for fil in os.listdir(basePath + "/" + f + "/" + fs):
      if "Fall" in fs:
        if "avi" in fil[-4:]:
          frmList = scale_and_resize_list_of_frames(video_to_frames(basePath + "/" + f + "/" + fs + "/" + fil))
          frmList = split_array_by_num(frmList)
          np.save("/content/fall_tensors/" +fil, frmList)
      else:
        if "avi" in fil[-4:]:
          frmList = scale_and_resize_list_of_frames(video_to_frames(basePath + "/" + f + "/" + fs + "/" + fil))
          frmList = split_array_by_num(frmList)
          np.save("/content/adl_tensors/"  +fil, frmList)

# %%
fallTensors = os.listdir("/content/fall_tensors")
dataset3 = tf.data.Dataset.from_tensor_slices(([np.load("/content/fall_tensors" + "/" +fallTensors[0])],[1]))
for f in fallTensors[1:]:
  dataset3 = dataset3.concatenate(tf.data.Dataset.from_tensor_slices(([np.load("/content/fall_tensors"+ "/"+ f)],[1])))
for f in os.listdir("/content/adl_tensors"):
  dataset3 = dataset3.concatenate(tf.data.Dataset.from_tensor_slices(([np.load("/content/adl_tensors" + "/" + f)],[0])))

# %% [markdown]
# Run this if dataset is already downloaded to Drive:

# %%
# Dataset 3
# !mkdir Dataset3
# !mkdir Dataset3/6637168987082036199
# !mkdir Dataset3/6637168987082036199/00000000.shard
shutil.copy("/content/drive/MyDrive/Caucafall_Dataset/6637168987082036199/00000000.shard/00000000.snapshot", "/content/Dataset3/6637168987082036199/00000000.shard")
shutil.copy("/content/drive/MyDrive/Caucafall_Dataset/dataset_spec.pb", "/content/Dataset3")
shutil.copy("/content/drive/MyDrive/Caucafall_Dataset/snapshot.metadata", "/content/Dataset3")

dataset3 = tf.data.Dataset.load("/content/Dataset3")

# %% [markdown]
# # Creating Combined Dataset

# %%
dataset2 = dataset2.map(lambda x, y: (tf.cast(x, tf.float32), y))
dataset3 = dataset3.map(lambda x, y: (tf.cast(x, tf.float32), y))
combined_dataset = dataset1.concatenate(dataset2).concatenate(dataset3)

# %%
combined_dataset.save("/content/Combined_Dataset")

# %%
dataset = tf.data.Dataset.load("/content/Combined_Dataset")

# %% [markdown]
# # Preprocessing Functions

# %%
def generate_train_test_val_splits(dataset,train_size,test_size,val_size):
  train_size = int(len(dataset)*train_size)
  test_size = int(len(dataset)*test_size)
  val_size = int(len(dataset)*val_size)
  dataset = dataset.shuffle(len(dataset))
  train_dataset = dataset.take(train_size)
  test_dataset = dataset.skip(train_size).take(test_size)
  val_dataset = dataset.skip(train_size+test_size).take(val_size)
  return train_dataset,test_dataset,val_dataset

# %%
def preprocess(sequence, label):
  sequence = sequence[:SEQUENCE_LENGTH]
  sequence = tf.pad(sequence, [[0, SEQUENCE_LENGTH - tf.shape(sequence)[0]], [0, 0], [0, 0], [0, 0]])
  return sequence, label

# %%
def prep_ds(dataset, batch_size=16):
  dataset = dataset.map(lambda x, y: (tf.image.resize(x, (IMAGE_HEIGHT, IMAGE_WIDTH)), y))
  dataset = dataset.batch(batch_size)
  dataset = dataset.prefetch(tf.data.AUTOTUNE)
  return dataset

# %% [markdown]
# # CNN and LSTM Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, LSTM, TimeDistributed, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import AUC, Precision, Recall

model = Sequential()

model.add(TimeDistributed(Conv2D(32, (3, 3), activation='relu', padding='same'), input_shape=(SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH, 3)))
model.add(TimeDistributed(MaxPooling2D((2, 2))))
model.add(TimeDistributed(Dropout(0.25)))

model.add(TimeDistributed(Conv2D(64, (3, 3), activation='relu', padding='same')))
model.add(TimeDistributed(MaxPooling2D((2, 2))))
model.add(TimeDistributed(Dropout(0.25)))

model.add(TimeDistributed(Conv2D(128, (3, 3), activation='relu', padding='same')))
model.add(TimeDistributed(MaxPooling2D((2, 2))))
model.add(TimeDistributed(Dropout(0.25)))

model.add(TimeDistributed(Flatten()))

model.add(LSTM(64, return_sequences=False))
model.add(Dropout(0.5))

model.add(Dense(32, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy', AUC(), Precision(), Recall()])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed (TimeDist  (None, 30, 128, 128, 32   896
#  ributed)                    )
#
#  time_distributed_1 (TimeDi  (None, 30, 64, 64, 32)    0
#  stributed)
#
#  time_distributed_2 (TimeDi  (None, 30, 64, 64, 32)    0
#  stributed)
#
#  time_distributed_3 (TimeDi  (None, 30, 64, 64, 64)    18496
#  stributed)
#
#  time_distributed_4 (TimeDi  (None, 30, 32, 32, 64)    0
#  stributed)
#
#  time_distributed_5 (TimeDi  (None, 30, 32, 32, 64)    0
#  stributed)
#
#  time_distributed_6 (TimeDi  (None, 30, 32, 32, 128)   73856
#  stributed)
#
#  time_distributed_7 (TimeDi  (None, 30, 16, 16, 128)   0
#  stributed)
#
#  time_distributed_8 (TimeDi  (None, 30, 16, 16, 128)   0
#  stributed)
#
#  time_distributed_9 (TimeDi  (None, 30, 32768)         0
#  stributed)
#
#  lstm (LSTM)                 (None, 64)                8405248
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense (Dense)               (None, 32)                2080
#
#  dropout_4 (Dropout)         (None, 32)                0
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 8500609 (32.43 MB)
# Trainable params: 8500609 (32.43 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Model Testing

# %%
train_ds, test_ds, val_ds = generate_train_test_val_splits(dataset, 0.8, 0.1, 0.1)

train_ds = train_ds.map(preprocess)
val_ds = val_ds.map(preprocess)
test_ds = test_ds.map(preprocess)

train_ds = prep_ds(train_ds)
val_ds = prep_ds(val_ds)
test_ds = prep_ds(test_ds)

start_time = time.process_time()
history = model.fit(train_ds, epochs=60, validation_data=val_ds)
test_loss, test_accuracy, test_auc, test_precision, test_recall = model.evaluate(test_ds)

print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
print("Test AUC:", test_auc)
print("Test Precision:", test_precision)
print("Test Recall:", test_recall)

start_time = time.process_time() - start_time
print("Time taken:", start_time)
# Out:
# Epoch 1/60
# 11/11 [==============================] - 16s 482ms/step - loss: 0.8011 - accuracy: 0.5465 - auc: 0.5531 - precision: 0.5703 - recall: 0.7604 - val_loss: 0.7566 - val_accuracy: 0.3333 - val_auc: 0.6276 - val_precision: 0.3333 - val_recall: 1.0000
# Epoch 2/60
# 11/11 [==============================] - 3s 157ms/step - loss: 0.7717 - accuracy: 0.5349 - auc: 0.5418 - precision: 0.5564 - recall: 0.7789 - val_loss: 0.6925 - val_accuracy: 0.5714 - val_auc: 0.4444 - val_precision: 0.5714 - val_recall: 1.0000
# Epoch 3/60
# 11/11 [==============================] - 3s 156ms/step - loss: 0.7257 - accuracy: 0.5174 - auc: 0.5306 - precision: 0.5586 - recall: 0.6458 - val_loss: 0.7003 - val_accuracy: 0.4286 - val_auc: 0.4769 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/60
# 11/11 [==============================] - 3s 160ms/step - loss: 0.7336 - accuracy: 0.5349 - auc: 0.4732 - precision: 0.5691 - recall: 0.7216 - val_loss: 0.7023 - val_accuracy: 0.3810 - val_auc: 0.7115 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/60
# 11/11 [==============================] - 3s 156ms/step - loss: 0.6942 - accuracy: 0.5174 - auc: 0.5421 - precision: 0.5410 - recall: 0.7097 - val_loss: 0.6895 - val_accuracy: 0.5238 - val_auc: 0.6727 - val_precision: 0.6667 - val_recall: 0.1818
# Epoch 6/60
# 11/11 [==============================] - 3s 156ms/step - loss: 0.7186 - accuracy: 0.4942 - auc: 0.4561 - precision: 0.5246 - recall: 0.6882 - val_loss: 0.6932 - val_accuracy: 0.4762 - val_auc: 0.6389 - val_precision: 1.0000 - val_recall: 0.0833
# Epoch 7/60
# 11/11 [==============================] - 3s 158ms/step - loss: 0.6790 - accuracy: 0.5581 - auc: 0.5629 - precision: 0.5981 - recall: 0.6598 - val_loss: 0.6774 - val_accuracy: 0.5238 - val_auc: 0.8636 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 8/60
# 11/11 [==============================] - 3s 155ms/step - loss: 0.6783 - accuracy: 0.5756 - auc: 0.5901 - precision: 0.5983 - recall: 0.7292 - val_loss: 0.6215 - val_accuracy: 0.5238 - val_auc: 0.7653 - val_precision: 0.8333 - val_recall: 0.3571
# Epoch 9/60
# 11/11 [==============================] - 3s 156ms/step - loss: 0.6562 - accuracy: 0.6105 - auc: 0.6489 - precision: 0.6286 - recall: 0.7021 - val_loss: 0.5889 - val_accuracy: 0.9524 - val_auc: 0.9327 - val_precision: 1.0000 - val_recall: 0.8750
# Epoch 10/60
# 11/11 [==============================] - 3s 158ms/step - loss: 0.6212 - accuracy: 0.6628 - auc: 0.6994 - precision: 0.6931 - recall: 0.7216 - val_loss: 0.5567 - val_accuracy: 0.5714 - val_auc: 0.9423 - val_precision: 1.0000 - val_recall: 0.3077
# Epoch 11/60
# 11/11 [==============================] - 3s 157ms/step - loss: 0.4961 - accuracy: 0.7558 - auc: 0.8333 - precision: 0.7802 - recall: 0.7634 - val_loss: 0.3506 - val_accuracy: 0.9048 - val_auc: 0.9615 - val_precision: 1.0000 - val_recall: 0.8462
# Epoch 12/60
# 11/11 [==============================] - 3s 156ms/step - loss: 0.4403 - accuracy: 0.7558 - auc: 0.8568 - precision: 0.7835 - recall: 0.7835 - val_loss: 0.3231 - val_accuracy: 0.8571 - val_auc: 0.8673 - val_precision: 0.8235 - val_recall: 1.0000
# Epoch 13/60
# 11/11 [==============================] - 3s 157ms/step - loss: 0.4160 - accuracy: 0.8140 - auc: 0.8849 - precision: 0.8155 - recall: 0.8660 - val_loss: 0.3567 - val_accuracy: 0.8095 - val_auc: 0.9439 - val_precision: 0.8125 - val_recall: 0.9286
# Epoch 14/60
# 11/11 [==============================] - 3s 159ms/step - loss: 0.3612 - accuracy: 0.8140 - auc: 0.9177 - precision: 0.8182 - recall: 0.8526 - val_loss: 0.2734 - val_accuracy: 0.8571 - val_auc: 0.9682 - val_precision: 1.0000 - val_recall: 0.7000
# Epoch 15/60
# 11/11 [==============================] - 3s 158ms/step - loss: 0.3404 - accuracy: 0.8256 - auc: 0.9243 - precision: 0.8795 - recall: 0.7849 - val_loss: 0.2874 - val_accuracy: 0.7619 - val_auc: 0.9864 - val_precision: 1.0000 - val_recall: 0.5455
# Epoch 16/60
# 11/11 [==============================] - 3s 157ms/step - loss: 0.3385 - accuracy: 0.8256 - auc: 0.9266 - precision: 0.8381 - recall: 0.8713 - val_loss: 0.2932 - val_accuracy: 0.8095 - val_auc: 0.9630 - val_precision: 0.8333 - val_recall: 0.8333
# Epoch 17/60
# 11/11 [==============================] - 3s 156ms/step - loss: 0.3675 - accuracy: 0.7965 - auc: 0.9110 - precision: 0.8000 - recall: 0.8261 - val_loss: 0.2955 - val_accuracy: 0.8095 - val_auc: 0.9537 - val_precision: 1.0000 - val_recall: 0.5556
# Epoch 18/60
# 11/11 [==============================] - 3s 157ms/step - loss: 0.3328 - accuracy: 0.8314 - auc: 0.9305 - precision: 0.8736 - recall: 0.8085 - val_loss: 0.3289 - val_accuracy: 0.8095 - val_auc: 0.9630 - val_precision: 0.7273 - val_recall: 0.8889
# Epoch 19/60
# 11/11 [==============================] - 3s 158ms/step - loss: 0.3171 - accuracy: 0.8372 - auc: 0.9333 - precision: 0.8317 - recall: 0.8842 - val_loss: 0.1729 - val_accuracy: 0.9524 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 0.9000
# Epoch 20/60
# 11/11 [==============================] - 3s 182ms/step - loss: 0.2987 - accuracy: 0.8198 - auc: 0.9318 - precision: 0.8247 - recall: 0.8511 - val_loss: 0.2770 - val_accuracy: 0.9048 - val_auc: 0.9636 - val_precision: 1.0000 - val_recall: 0.8000
# Epoch 21/60
# 11/11 [==============================] - 3s 156ms/step - loss: 0.2827 - accuracy: 0.8430 - auc: 0.9430 - precision: 0.8384 - recall: 0.8830 - val_loss: 0.2457 - val_accuracy: 0.8095 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 0.6364
# Epoch 22/60
# 11/11 [==============================] - 3s 156ms/step - loss: 0.2936 - accuracy: 0.8430 - auc: 0.9472 - precision: 0.9213 - recall: 0.8039 - val_loss: 0.2454 - val_accuracy: 0.9048 - val_auc: 0.9907 - val_precision: 1.0000 - val_recall: 0.8333
# Epoch 23/60
# 11/11 [==============================] - 3s 159ms/step - loss: 0.3261 - accuracy: 0.8372 - auc: 0.9276 - precision: 0.8155 - recall: 0.9032 - val_loss: 0.2120 - val_accuracy: 0.8095 - val_auc: 0.9630 - val_precision: 0.8333 - val_recall: 0.8333
# Epoch 24/60
# 11/11 [==============================] - 3s 158ms/step - loss: 0.2749 - accuracy: 0.8721 - auc: 0.9488 - precision: 0.9121 - recall: 0.8557 - val_loss: 0.3588 - val_accuracy: 0.7619 - val_auc: 0.9615 - val_precision: 1.0000 - val_recall: 0.6154
# Epoch 25/60
# 11/11 [==============================] - 3s 155ms/step - loss: 0.2979 - accuracy: 0.8198 - auc: 0.9448 - precision: 0.9121 - recall: 0.7830 - val_loss: 0.1728 - val_accuracy: 0.9524 - val_auc: 0.9955 - val_precision: 1.0000 - val_recall: 0.9091
# Epoch 26/60
# 11/11 [==============================] - 3s 158ms/step - loss: 0.2266 - accuracy: 0.8779 - auc: 0.9682 - precision: 0.8687 - recall: 0.9149 - val_loss: 0.2651 - val_accuracy: 0.8095 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 0.6364
# Epoch 27/60
# 11/11 [==============================] - 3s 161ms/step - loss: 0.2263 - accuracy: 0.8721 - auc: 0.9713 - precision: 0.9390 - recall: 0.8191 - val_loss: 0.3659 - val_accuracy: 0.7143 - val_auc: 0.9364 - val_precision: 1.0000 - val_recall: 0.4545
# Epoch 28/60
# 11/11 [==============================] - 3s 158ms/step - loss: 0.2530 - accuracy: 0.8430 - auc: 0.9565 - precision: 0.9043 - recall: 0.8252 - val_loss: 0.2486 - val_accuracy: 0.8095 - val_auc: 0.9815 - val_precision: 1.0000 - val_recall: 0.6667
# Epoch 29/60
# 11/11 [==============================] - 3s 158ms/step - loss: 0.2639 - accuracy: 0.8721 - auc: 0.9535 - precision: 0.8776 - recall: 0.8958 - val_loss: 0.2417 - val_accuracy: 0.8095 - val_auc: 0.9592 - val_precision: 0.9167 - val_recall: 0.7857
# Epoch 30/60
# 11/11 [==============================] - 3s 158ms/step - loss: 0.2235 - accuracy: 0.8837 - auc: 0.9671 - precision: 0.9080 - recall: 0.8681 - val_loss: 0.1713 - val_accuracy: 0.9524 - val_auc: 0.9815 - val_precision: 0.9231 - val_recall: 1.0000
# Epoch 31/60
# 11/11 [==============================] - 3s 163ms/step - loss: 0.2198 - accuracy: 0.9070 - auc: 0.9703 - precision: 0.9158 - recall: 0.9158 - val_loss: 0.2074 - val_accuracy: 0.9048 - val_auc: 0.9722 - val_precision: 0.8182 - val_recall: 1.0000
# Epoch 32/60
# 11/11 [==============================] - 3s 158ms/step - loss: 0.2147 - accuracy: 0.9128 - auc: 0.9729 - precision: 0.9082 - recall: 0.9368 - val_loss: 0.2356 - val_accuracy: 0.8571 - val_auc: 0.9545 - val_precision: 0.8182 - val_recall: 0.9000
# Epoch 33/60
# 11/11 [==============================] - 3s 159ms/step - loss: 0.2097 - accuracy: 0.9128 - auc: 0.9726 - precision: 0.9022 - recall: 0.9326 - val_loss: 0.0691 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 34/60
# 11/11 [==============================] - 3s 161ms/step - loss: 0.1986 - accuracy: 0.9070 - auc: 0.9750 - precision: 0.9239 - recall: 0.9043 - val_loss: 0.0745 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 35/60
# 11/11 [==============================] - 3s 156ms/step - loss: 0.1806 - accuracy: 0.9070 - auc: 0.9781 - precision: 0.8922 - recall: 0.9479 - val_loss: 0.1202 - val_accuracy: 0.9524 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 0.8889
# Epoch 36/60
# 11/11 [==============================] - 3s 157ms/step - loss: 0.2127 - accuracy: 0.9070 - auc: 0.9736 - precision: 0.9302 - recall: 0.8889 - val_loss: 0.0949 - val_accuracy: 0.9524 - val_auc: 1.0000 - val_precision: 0.9000 - val_recall: 1.0000
# Epoch 37/60
# 11/11 [==============================] - 3s 162ms/step - loss: 0.1916 - accuracy: 0.9128 - auc: 0.9771 - precision: 0.9213 - recall: 0.9111 - val_loss: 0.0387 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 38/60
# 11/11 [==============================] - 3s 159ms/step - loss: 0.1487 - accuracy: 0.9419 - auc: 0.9885 - precision: 0.9592 - recall: 0.9400 - val_loss: 0.1851 - val_accuracy: 0.9048 - val_auc: 0.9818 - val_precision: 0.8462 - val_recall: 1.0000
# Epoch 39/60
# 11/11 [==============================] - 3s 162ms/step - loss: 0.1455 - accuracy: 0.9593 - auc: 0.9871 - precision: 0.9574 - recall: 0.9677 - val_loss: 0.1140 - val_accuracy: 0.9524 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 0.9000
# Epoch 40/60
# 11/11 [==============================] - 3s 165ms/step - loss: 0.1165 - accuracy: 0.9593 - auc: 0.9936 - precision: 0.9457 - recall: 0.9775 - val_loss: 0.1518 - val_accuracy: 0.9524 - val_auc: 0.9909 - val_precision: 0.9167 - val_recall: 1.0000
# Epoch 41/60
# 11/11 [==============================] - 3s 161ms/step - loss: 0.1568 - accuracy: 0.9360 - auc: 0.9857 - precision: 0.9674 - recall: 0.9175 - val_loss: 0.0645 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 42/60
# 11/11 [==============================] - 3s 163ms/step - loss: 0.1298 - accuracy: 0.9535 - auc: 0.9915 - precision: 0.9400 - recall: 0.9792 - val_loss: 0.0481 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 43/60
# 11/11 [==============================] - 3s 161ms/step - loss: 0.1634 - accuracy: 0.9419 - auc: 0.9805 - precision: 0.9368 - recall: 0.9570 - val_loss: 0.0640 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 44/60
# 11/11 [==============================] - 3s 161ms/step - loss: 0.1227 - accuracy: 0.9477 - auc: 0.9922 - precision: 0.9570 - recall: 0.9468 - val_loss: 0.0373 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 45/60
# 11/11 [==============================] - 3s 161ms/step - loss: 0.1209 - accuracy: 0.9593 - auc: 0.9917 - precision: 0.9505 - recall: 0.9796 - val_loss: 0.1079 - val_accuracy: 0.9524 - val_auc: 1.0000 - val_precision: 0.9231 - val_recall: 1.0000
# Epoch 46/60
# 11/11 [==============================] - 3s 161ms/step - loss: 0.0952 - accuracy: 0.9651 - auc: 0.9974 - precision: 0.9794 - recall: 0.9596 - val_loss: 0.0674 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 47/60
# 11/11 [==============================] - 3s 162ms/step - loss: 0.1102 - accuracy: 0.9593 - auc: 0.9948 - precision: 0.9674 - recall: 0.9570 - val_loss: 0.1260 - val_accuracy: 0.9524 - val_auc: 0.9904 - val_precision: 0.9286 - val_recall: 1.0000
# Epoch 48/60
# 11/11 [==============================] - 3s 162ms/step - loss: 0.0737 - accuracy: 0.9767 - auc: 0.9983 - precision: 0.9889 - recall: 0.9674 - val_loss: 0.0211 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 49/60
# 11/11 [==============================] - 3s 161ms/step - loss: 0.0969 - accuracy: 0.9767 - auc: 0.9930 - precision: 0.9688 - recall: 0.9894 - val_loss: 0.0350 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 50/60
# 11/11 [==============================] - 3s 160ms/step - loss: 0.0818 - accuracy: 0.9709 - auc: 0.9953 - precision: 0.9785 - recall: 0.9681 - val_loss: 0.0984 - val_accuracy: 0.9524 - val_auc: 1.0000 - val_precision: 0.9231 - val_recall: 1.0000
# Epoch 51/60
# 11/11 [==============================] - 3s 162ms/step - loss: 0.0804 - accuracy: 0.9651 - auc: 0.9951 - precision: 0.9490 - recall: 0.9894 - val_loss: 0.0264 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 52/60
# 11/11 [==============================] - 3s 160ms/step - loss: 0.0685 - accuracy: 0.9826 - auc: 0.9953 - precision: 0.9794 - recall: 0.9896 - val_loss: 0.0283 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 53/60
# 11/11 [==============================] - 3s 158ms/step - loss: 0.0845 - accuracy: 0.9593 - auc: 0.9958 - precision: 0.9500 - recall: 0.9794 - val_loss: 0.0333 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 54/60
# 11/11 [==============================] - 3s 160ms/step - loss: 0.0640 - accuracy: 0.9709 - auc: 0.9990 - precision: 0.9894 - recall: 0.9588 - val_loss: 0.0044 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 55/60
# 11/11 [==============================] - 3s 161ms/step - loss: 0.0822 - accuracy: 0.9826 - auc: 0.9925 - precision: 0.9694 - recall: 1.0000 - val_loss: 0.0068 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 56/60
# 11/11 [==============================] - 3s 161ms/step - loss: 0.0517 - accuracy: 0.9884 - auc: 0.9986 - precision: 0.9800 - recall: 1.0000 - val_loss: 0.0081 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 57/60
# 11/11 [==============================] - 3s 164ms/step - loss: 0.0541 - accuracy: 0.9884 - auc: 0.9986 - precision: 0.9898 - recall: 0.9898 - val_loss: 0.0644 - val_accuracy: 0.9524 - val_auc: 1.0000 - val_precision: 0.9091 - val_recall: 1.0000
# Epoch 58/60
# 11/11 [==============================] - 3s 163ms/step - loss: 0.0437 - accuracy: 0.9884 - auc: 0.9998 - precision: 0.9798 - recall: 1.0000 - val_loss: 0.0125 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 59/60
# 11/11 [==============================] - 3s 163ms/step - loss: 0.0575 - accuracy: 0.9767 - auc: 0.9977 - precision: 0.9794 - recall: 0.9794 - val_loss: 0.0050 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 60/60
# 11/11 [==============================] - 3s 159ms/step - loss: 0.0478 - accuracy: 0.9884 - auc: 0.9993 - precision: 1.0000 - recall: 0.9780 - val_loss: 0.0087 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# 2/2 [==============================] - 1s 18ms/step - loss: 0.0062 - accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000
# Test Loss: 0.006176857743412256
# Test Accuracy: 1.0
# Test AUC: 1.0
# Test Precision: 1.0
# Test Recall: 1.0
# Time taken: 212.522985056

# %% [markdown]
# # Saving Figures and Model

# %%
def create_plot(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    auc = history.history['auc']
    val_auc = history.history['val_auc']
    precision = history.history['precision']
    val_precision = history.history['val_precision']
    recall = history.history['recall']
    val_recall = history.history['val_recall']
    epochs = range(len(acc))

    # Plotting Accuracy
    plt.figure(figsize=(6, 6))
    plt.plot(epochs, acc, 'bo-', label='Training accuracy')
    plt.plot(epochs, val_acc, 'ro-', label='Validation accuracy')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.show()
    plt.savefig('/content/Figures/accuracy.png')

    # Plotting Loss
    plt.figure(figsize=(6, 6))
    plt.plot(epochs, loss, 'bo-', label='Training loss')
    plt.plot(epochs, val_loss, 'ro-', label='Validation loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()
    plt.savefig('/content/Figures/loss.png')

    # Plotting AUC
    plt.figure(figsize=(6, 6))
    plt.plot(epochs, auc, 'bo-', label='Training AUC')
    plt.plot(epochs, val_auc, 'ro-', label='Validation AUC')
    plt.title('Training and Validation AUC')
    plt.xlabel('Epochs')
    plt.ylabel('AUC')
    plt.legend()
    plt.show()
    plt.savefig('/content/Figures/auc.png')

    # Plotting Precision
    plt.figure(figsize=(6, 6))
    plt.plot(epochs, precision, 'bo-', label='Training Precision')
    plt.plot(epochs, val_precision, 'ro-', label='Validation Precision')
    plt.title('Training and Validation Precision')
    plt.xlabel('Epochs')
    plt.ylabel('Precision')
    plt.legend()
    plt.show()
    plt.savefig('/content/Figures/precision.png')

    # Plotting Recall
    plt.figure(figsize=(6, 6))
    plt.plot(epochs, recall, 'bo-', label='Training Recall')
    plt.plot(epochs, val_recall, 'ro-', label='Validation Recall')
    plt.title('Training and Validation Recall')
    plt.xlabel('Epochs')
    plt.ylabel('Recall')
    plt.legend()
    plt.show()
    plt.savefig('/content/Figures/recall.png')

# %%
create_plot(history)

# %%
save_model(model, 'my_model.h5')
# Out:
# <ipython-input-18-9db76e4b5ae4>:1: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   save_model(model, 'my_model.h5')
